# %% [markdown]
# <a href="https://colab.research.google.com/github/offmannn/a2/blob/master/lesson3_camvid_offman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Image segmentation with CamVid

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
URLs.CAMVID
# Out:
# 'https://s3.amazonaws.com/fast-ai-imagelocal/camvid'

# %%
path=untar_data(url='https://s3.amazonaws.com/fast-ai-imagelocal/camvid',fname='root/.fastai/data/camvid',dest='/content/drive/My Drive')

# %%
path = untar_datafinds.CAMVID)
path.ls()
# Out:
# [PosixPath('/home/ubuntu/.fastai/data/camvid/images'),
#  PosixPath('/home/ubuntu/.fastai/data/camvid/codes.txt'),
#  PosixPath('/home/ubuntu/.fastai/data/camvid/labels'),
#  PosixPath('/home/ubuntu/.fastai/data/camvid/valid.txt')]

# %% [markdown]
# ☝not used ✍helps to find_ location_ of data🍻

# %%
path_lbl = path/'labels'
path_img = path/'images'

# %% [markdown]
# ## Subset classes

# %%
# path = Path('./data/camvid-small')

# def get_y_fn(x): return Path(str(x.parent)+'annot')/x.name

# codes = array(['Sky', 'Building', 'Pole', 'Road', 'Sidewalk', 'Tree',
#     'Sign', 'Fence', 'Car', 'Pedestrian', 'Cyclist', 'Void'])

# src = (SegmentationItemList.from_folder(path)
#        .split_by_folder(valid='val')
#        .label_from_func(get_y_fn, classes=codes))

# bs=8
# data = (src.transform(get_transforms(), tfm_y=True)
#         .databunch(bs=bs)
#         .normalize(imagenet_stats))

# %% [markdown]
# ## Data

# %%
fnames = get_image_files(path_img)
fnames[:3]
# Out:
# [PosixPath('/content/drive/My Drive/camvid/images/0016E5_00750.png'),
#  PosixPath('/content/drive/My Drive/camvid/images/0006R0_f00990.png'),
#  PosixPath('/content/drive/My Drive/camvid/images/0016E5_07410.png')]

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:3]
# Out:
# [PosixPath('/content/drive/My Drive/camvid/labels/0001TP_009690_P.png'),
#  PosixPath('/content/drive/My Drive/camvid/labels/0016E5_08073_P.png'),
#  PosixPath('/content/drive/My Drive/camvid/labels/0016E5_04470_P.png')]

# %%
img_f = fnames[0]
img = open_image(img_f)
img.show(figsize=(5,5))

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([720, 960]), tensor([[[21, 21, 21,  ..., 21, 21, 21],
#           [21, 21, 21,  ..., 21, 21, 21],
#           [21, 21, 21,  ..., 21, 21, 21],
#           ...,
#           [18, 18, 18,  ..., 17, 17, 17],
#           [18, 18, 18,  ..., 17, 17, 17],
#           [18, 18, 18,  ..., 17, 17, 17]]]))

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %% [markdown]
# ## Datasets

# %%
size = src_size//2

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=8
else:           bs=4
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# using bs=8, have 11430MB of GPU RAM free

# %% [markdown]
# ☝not used🏄

# %%
src = (SegmentationItemList.from_folder(path_img)
       .split_by_fname_file('../valid.txt')
       .label_from_func(get_y_fn, classes=codes))

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# ## Model

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid
# metrics=accuracy

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
lr=3e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.9)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.193659</td>
#       <td>0.766747</td>
#       <td>0.820934</td>
#       <td>03:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.857639</td>
#       <td>0.673417</td>
#       <td>0.839110</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.684679</td>
#       <td>0.584806</td>
#       <td>0.833919</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.634350</td>
#       <td>0.546628</td>
#       <td>0.857961</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.612107</td>
#       <td>0.568709</td>
#       <td>0.846193</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.unfreeze()

# %%
lrs = slice(lr/400,lr/4)

# %%
learn.fit_one_cycle(2, lrs, pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.597296</td>
#       <td>0.497972</td>
#       <td>0.865551</td>
#       <td>03:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.551727</td>
#       <td>0.443082</td>
#       <td>0.875613</td>
#       <td>03:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2');

# %% [markdown]
# ## Go big

# %% [markdown]
# You may have to restart your kernel and come back to this stage if you run out of memory, and may also need to decrease `bs`.

# %%
learn.destroy()

size = src_size

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=3
else:           bs=1
print(f"using bs={bs}, have {free}MB of GPU RAM free")

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
learn.load('stage-2');

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
lr=1e-3

# %%
learn.fit_one_cycle(2, slice(lr), pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.487225</td>
#       <td>0.422668</td>
#       <td>0.880521</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.477049</td>
#       <td>0.416995</td>
#       <td>0.882409</td>
#       <td>03:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-big')

# %%
learn.load('stage-1-big');

# %%
learn.unfreeze()

# %%
lrs = slice(1e-6,lr/10)

# %%
learn.fit_one_cycle(4, lrs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.429604</td>
#       <td>0.387244</td>
#       <td>0.888795</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.416562</td>
#       <td>0.364077</td>
#       <td>0.896198</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.404204</td>
#       <td>0.360938</td>
#       <td>0.896475</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.391858</td>
#       <td>0.357505</td>
#       <td>0.897163</td>
#       <td>03:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2-big')

# %%
learn.load('stage-2-big');

# %%
learn.show_results(rows=3, figsize=(10,10))

# %%
learn.export()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 59

# %% [markdown]
# ## fin

# %%
path
# Out:
# PosixPath('/content/drive/My Drive/camvid')
